# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

fig = plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')

# %%
P = "P"
A = "A"

# %%
class Fee:
    def __init__(self, type, value, min_fee=0):
        self.type = type
        self.value = value
        self.min_fee = min_fee
        
        self.P = P
        self.A = A
        
    def __mul__(self, other):
        if (self.type == self.P):
            return max((self.value / 100) * other, self.min_fee)
        elif (self.type == self.A):
            return self.value
        return self.value
    def __rmul__(self, other):
        return self.__mul__(other)

# %%
class InvestFund:
    def __init__(self, conversion_fee, action_fee, period_fee):
        self.conversion_fee = conversion_fee
        self.action_fee = action_fee
        self.period_fee = period_fee
        
    def calculate_period_fee(self, period_invested_money, whole):
        fee_on_investment = 0
        
        fee_on_investment += period_invested_money * self.conversion_fee
        period_invested_money -= fee_on_investment
        
        fee_on_investment += period_invested_money * self.action_fee
        
        unrelated_fee = whole * self.period_fee 
        
        return fee_on_investment, unrelated_fee

# %%
periods = 12 * 10
period_stock_market_factors = 1.004867551 * np.ones(periods) 
invested_money = 10000 * np.ones(periods)
usd_to_nis = 3.22 * np.ones(periods)

conversion_fee = Fee(P, 0.18)
action_fee = Fee(A, 20)
period_fee = Fee(A, 20)

altchuler = InvestFund(Fee(P, 0.18), Fee(A, 20), Fee(A, 20))

# %%
def whole_without_invest(invested_money):
    return np.cumsum(invested_money)

# %%
def whole_invest_without_fee(invested_money, period_stock_market_factors):
    output = []
    last_whole = 0
    for (index, factor) in enumerate(period_stock_market_factors):
        output.append(last_whole * factor + invested_money[index])
        last_whole = output[-1]
        
    return np.array(output)

# %%
def whole_invest(invested_money, period_stock_market_factors, invest_fund):
    whole_output = []
    cum_fees = []
    
    last_whole = 0
    
    for (index, factor) in enumerate(period_stock_market_factors):
        period_invested_money = invested_money[index]
        # Calculate the whole as the last period yield
        whole = last_whole * factor 
        
        # Subtract all fees
        fee, unrelated_fee = invest_fund.calculate_period_fee(period_invested_money, whole)
        whole -= fee
        cum_fees.append(unrelated_fee)
        
        whole += period_invested_money
        
        whole_output.append(whole)
        
        last_whole = whole
        
    output = np.array(whole_output) - np.array(cum_fees)
    
    return output

# %%
file = "./Stocks/S&P_500_1927-2020.csv"
sp500_df = pd.read_csv(file)

sp500_df["Date"] = pd.to_datetime(sp500_df["Date"])

sp500_df.index = sp500_df["Date"] 
sp500_df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  23362.000000  23362.000000  23362.000000  23362.000000  23362.000000
# mean     492.089598    494.982932    489.007977    492.190579    492.190579
# std      736.933970    740.900884    732.609681    737.041220    737.041220
# min        4.400000      4.400000      4.400000      4.400000      4.400000
# 25%       23.879999     23.879999     23.879999     23.879999     23.879999
# 50%       99.610001    100.405003     98.825001     99.610001     99.610001
# 75%      843.394989    851.802475    832.087479    843.429993    843.429993
# max     3750.010010   3760.199951   3730.209961   3756.070068   3756.070068
#
#              Volume
# count  2.336200e+04
# mean   7.757468e+08
# std    1.493062e+09
# min    0.000000e+00
# 25%    1.290000e+06
# 50%    1.747500e+07
# 75%    5.516100e+08
# max    1.145623e+10

# %%
def cut_by_dates(df, start_date, end_date):
    start = df.index.searchsorted(dt.datetime(*start_date))
    end = df.index.searchsorted(dt.datetime(*end_date))

    return df.iloc[start:end]

def get_factors_df(df, close_key="Close", index_key="Date"):
    close_values = df[close_key].to_numpy()

    factors = [close_values[index + 1] / close_values[index] for index in range(len(close_values) - 1)]

    return pd.DataFrame({index_key: df[index_key][1:], "Values": factors})

# %%
start = (1980, 1, 1)
end = (2020, 1, 1)

sp500_range_cut_df = cut_by_dates(sp500_df, start, end)

first_of_month_indices = [date.day == 1 for date in sp500_range_cut_df["Date"]]

sp500_monthly = sp500_range_cut_df[first_of_month_indices]

factors_df = get_factors_df(sp500_monthly)

# %%
fig, (sub1, sub2) = plt.subplots(1, 2, figsize=[16, 8])

fig.suptitle("S&P 500")

sub1.plot(sp500_monthly["Date"], sp500_monthly["Close"])
sub1.set_title("Absolute")

sub2.plot(factors_df["Date"], factors_df["Values"])
sub2.set_title("Growth")
# Out:
# Text(0.5, 1.0, 'Growth')
